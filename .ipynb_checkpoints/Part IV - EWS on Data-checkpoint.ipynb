# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#EWS-on-data" data-toc-modified-id="EWS-on-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>EWS on data</a></span><ul class="toc-item"><li><span><a href="#Import-some-libraries" data-toc-modified-id="Import-some-libraries-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Import some libraries</a></span><ul class="toc-item"><li><span><a href="#Get-data-for-critical-patients" data-toc-modified-id="Get-data-for-critical-patients-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Get data for critical patients</a></span><ul class="toc-item"><li><span><a href="#Alkaline-Phosphatase" data-toc-modified-id="Alkaline-Phosphatase-1.1.1.1"><span class="toc-item-num">1.1.1.1&nbsp;&nbsp;</span>Alkaline Phosphatase</a></span></li><li><span><a href="#Cytokines" data-toc-modified-id="Cytokines-1.1.1.2"><span class="toc-item-num">1.1.1.2&nbsp;&nbsp;</span>Cytokines</a></span></li></ul></li><li><span><a href="#Apply-EWS" data-toc-modified-id="Apply-EWS-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Apply EWS</a></span><ul class="toc-item"><li><span><a href="#Standard-Deviation" data-toc-modified-id="Standard-Deviation-1.1.2.1"><span class="toc-item-num">1.1.2.1&nbsp;&nbsp;</span>Standard Deviation</a></span><ul class="toc-item"><li><span><a href="#Alkaline-phosphatase" data-toc-modified-id="Alkaline-phosphatase-1.1.2.1.1"><span class="toc-item-num">1.1.2.1.1&nbsp;&nbsp;</span>Alkaline phosphatase</a></span></li><li><span><a href="#Cytokines" data-toc-modified-id="Cytokines-1.1.2.1.2"><span class="toc-item-num">1.1.2.1.2&nbsp;&nbsp;</span>Cytokines</a></span></li></ul></li><li><span><a href="#Skewness" data-toc-modified-id="Skewness-1.1.2.2"><span class="toc-item-num">1.1.2.2&nbsp;&nbsp;</span>Skewness</a></span><ul class="toc-item"><li><span><a href="#Alkaline-phosphatase" data-toc-modified-id="Alkaline-phosphatase-1.1.2.2.1"><span class="toc-item-num">1.1.2.2.1&nbsp;&nbsp;</span>Alkaline phosphatase</a></span></li><li><span><a href="#Cytokines" data-toc-modified-id="Cytokines-1.1.2.2.2"><span class="toc-item-num">1.1.2.2.2&nbsp;&nbsp;</span>Cytokines</a></span></li></ul></li><li><span><a href="#Kurtosis" data-toc-modified-id="Kurtosis-1.1.2.3"><span class="toc-item-num">1.1.2.3&nbsp;&nbsp;</span>Kurtosis</a></span><ul class="toc-item"><li><span><a href="#Alkaline-phosphatase" data-toc-modified-id="Alkaline-phosphatase-1.1.2.3.1"><span class="toc-item-num">1.1.2.3.1&nbsp;&nbsp;</span>Alkaline phosphatase</a></span></li><li><span><a href="#Cytokines" data-toc-modified-id="Cytokines-1.1.2.3.2"><span class="toc-item-num">1.1.2.3.2&nbsp;&nbsp;</span>Cytokines</a></span></li></ul></li><li><span><a href="#Autocorrelation-at-lag-1" data-toc-modified-id="Autocorrelation-at-lag-1-1.1.2.4"><span class="toc-item-num">1.1.2.4&nbsp;&nbsp;</span>Autocorrelation at lag 1</a></span><ul class="toc-item"><li><span><a href="#Alkaline-Phosphatase" data-toc-modified-id="Alkaline-Phosphatase-1.1.2.4.1"><span class="toc-item-num">1.1.2.4.1&nbsp;&nbsp;</span>Alkaline Phosphatase</a></span></li><li><span><a href="#Cytokines" data-toc-modified-id="Cytokines-1.1.2.4.2"><span class="toc-item-num">1.1.2.4.2&nbsp;&nbsp;</span>Cytokines</a></span></li></ul></li><li><span><a href="#Conditional-heteroskedasticity" data-toc-modified-id="Conditional-heteroskedasticity-1.1.2.5"><span class="toc-item-num">1.1.2.5&nbsp;&nbsp;</span>Conditional heteroskedasticity</a></span><ul class="toc-item"><li><span><a href="#Alkaline-phosphatase" data-toc-modified-id="Alkaline-phosphatase-1.1.2.5.1"><span class="toc-item-num">1.1.2.5.1&nbsp;&nbsp;</span>Alkaline phosphatase</a></span></li><li><span><a href="#Cytokines" data-toc-modified-id="Cytokines-1.1.2.5.2"><span class="toc-item-num">1.1.2.5.2&nbsp;&nbsp;</span>Cytokines</a></span></li></ul></li><li><span><a href="#Time-varying-AR" data-toc-modified-id="Time-varying-AR-1.1.2.6"><span class="toc-item-num">1.1.2.6&nbsp;&nbsp;</span>Time-varying AR</a></span><ul class="toc-item"><li><span><a href="#Alkaline-phosphatase" data-toc-modified-id="Alkaline-phosphatase-1.1.2.6.1"><span class="toc-item-num">1.1.2.6.1&nbsp;&nbsp;</span>Alkaline phosphatase</a></span></li><li><span><a href="#Cytokines" data-toc-modified-id="Cytokines-1.1.2.6.2"><span class="toc-item-num">1.1.2.6.2&nbsp;&nbsp;</span>Cytokines</a></span></li></ul></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # EWS on data
# ## Import some libraries

# %%
from utils import *
import Parameters as prms
import APPIREDII_Cytokines_Parser as cyto
import APPIREDII_Blood_Params_Parser as dp

import pandas as pd
import matplotlib.pylab as plt

# %%
cyto_fle = prms.cyto_fle
sample_fle = prms.sample_fle
trt_fle = prms.trt_fle
german_hospital_file = prms.german_hospital_file
dutch_hospital_file = prms.dutch_hospital_file
treatment_file = prms.treatment_file

# %% [markdown]
# ### Get data for critical patients
#
# Pro-inflammatory cytokines, Anti-inflammatory Cytokines, Alkaline Phosphatase in plasma
#
# Critical patients. All of them are from the Placebo group (13, 16, and 38)

# %%
cases = [5]
case_names = ['', '', '', 'No AP', 'Placebo', 'bIAP']
critical_patients = ['13', '16', '38']
treatment = 'Placebo'

# %% [markdown]
# #### Alkaline Phosphatase

# %%
df_AP, df_AP_median = dp.get_data(german_hospital_file=german_hospital_file,
                                   dutch_hospital_file=dutch_hospital_file,
                                   treatment_file=treatment_file,
                                   parameter_name='AlkFosf',
                                   restrict=False,
                                   treatment=treatment,
                                   patients=critical_patients,
                                   do_binning=True)

# %%
df_AP_crit = df_AP[df_AP.patno.isin(critical_patients)].reset_index(drop=True)
df_AP_crit = df_AP_crit[['patno', 'alkfosf', 'time']]
df_AP_crit.head()
# Out:
#   patno  alkfosf      time
# 0    13    129.0 -5.400000
# 1    13    142.0  0.000000
# 2    13     67.0  0.016667
# 3    13     90.0  2.683333
# 4    13     85.0  7.650000

# %% [markdown]
# #### Cytokines

# %%
df_cyto = cyto.get_data(ct_fle=cyto_fle,
                        smpl_fle=sample_fle,
                        trt_fle=trt_fle,
                        colhd='sample')

df_cyto.patno = df_cyto.patno.astype(str)
df_cyto.rename(columns = {'sample':'time'}, inplace = True)

# %%
df_cyto_crit = df_cyto[df_cyto.patno.isin(critical_patients)].reset_index(drop=True)
df_cyto_crit = df_cyto_crit[['patno', 'il6', 'il10', 'time']]
df_cyto_crit.head()
# Out:
#   patno           il6          il10  time
# 0    16  4.300000e+05  9.288000e+05  -1.0
# 1    16  8.714667e+05  4.609600e+06   0.0
# 2    16  1.811733e+06  2.668867e+06   1.3
# 3    16  1.831800e+06  2.287600e+06   3.0
# 4    16  8.439753e+07  7.235467e+06   4.0

# %% [markdown]
# ### Apply EWS
# #### Standard Deviation
# ##### Alkaline phosphatase

# %%
for patient in critical_patients:
    dataset = df_AP_crit[df_AP_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='alkfosf', 
         noise_name = f'Patient {patient}', 
         immune_name = 'Alkaline Phosphatase', 
         method_name = 'STD', 
         method = do_ews_std,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# ##### Cytokines

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il6', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL6', 
         method_name = 'STD', 
         method = do_ews_std,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il10', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL10', 
         method_name = 'STD', 
         method = do_ews_std,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# #### Skewness
# ##### Alkaline phosphatase

# %%
for patient in critical_patients:
    dataset = df_AP_crit[df_AP_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='alkfosf', 
         noise_name = f'Patient {patient}', 
         immune_name = 'Alkaline Phosphatase', 
         method_name = 'Skewness', 
         method = do_ews_skew,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# ##### Cytokines

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il6', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL6', 
         method_name = 'Skewness', 
         method = do_ews_skew,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il10', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL10', 
         method_name = 'Skewness', 
         method = do_ews_skew,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# #### Kurtosis
# ##### Alkaline phosphatase

# %%
for patient in critical_patients:
    dataset = df_AP_crit[df_AP_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='alkfosf', 
         noise_name = f'Patient {patient}', 
         immune_name = 'Alkaline Phosphatase', 
         method_name = 'Kurtosis', 
         method = do_ews_kurt,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# ##### Cytokines

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il6', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL6', 
         method_name = 'Kurtosis', 
         method = do_ews_kurt,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il10', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL10', 
         method_name = 'Kurtosis', 
         method = do_ews_kurt,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# #### Autocorrelation at lag 1
# ##### Alkaline Phosphatase

# %%
for patient in critical_patients:
    dataset = df_AP_crit[df_AP_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='alkfosf', 
         noise_name = f'Patient {patient}', 
         immune_name = 'Alkaline Phosphatase', 
         method_name = 'Autocorrelation', 
         method = do_ews_auto,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)
# Out:
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:657: FutureWarning: The default number of lags is changing from 40 tomin(int(10 * np.log10(nobs)), nobs - 1) after 0.12is released. Set the number of lags to an integer to  silence this warning.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/stattools.py:667: FutureWarning: fft=True will become the default after the release of the 0.12 release of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(

# %% [markdown]
# ##### Cytokines

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il6', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL6', 
         method_name = 'Autocorrelation', 
         method = do_ews_auto,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il10', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL10', 
         method_name = 'Autocorrelation', 
         method = do_ews_auto,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# #### Conditional heteroskedasticity
# #####  Alkaline phosphatase

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

from statsmodels.stats.diagnostic import het_white
from statsmodels.compat import lzip
from patsy import dmatrices

# %%
for patient in critical_patients:
    dataset = df_AP_crit[df_AP_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='alkfosf', 
         noise_name = f'Patient {patient}', 
         immune_name = 'Alkaline Phosphatase', 
         method_name = 'CH', 
         method = do_ews_ch,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# ##### Cytokines

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(
        drop=True)
    plot(data=dataset,
         immune='il6',
         noise_name=f'Patient {patient}',
         immune_name='IL6',
         method_name='CH',
         method=do_ews_ch,
         win_size=len(dataset)/2,
         time='time',
         supfs=18)

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il10', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL10', 
         method_name = 'CH', 
         method = do_ews_ch,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)

# %% [markdown]
# #### Time-varying AR
# ##### Alkaline phosphatase

# %%
for patient in critical_patients:
    dataset = df_AP_crit[df_AP_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='alkfosf', 
         noise_name = f'Patient {patient}', 
         immune_name = 'Alkaline Phosphatase', 
         method_name = 'Time-varying AR', 
         method = do_ews_ar,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)
# Out:
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# ...

# %% [markdown]
# ##### Cytokines

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(drop=True)
    plot(data=dataset, 
         immune='il6', 
         noise_name = f'Patient {patient}', 
         immune_name = 'IL6', 
         method_name = 'Time-varying AR', 
         method = do_ews_ar,
         win_size = len(dataset)/2,
        time = 'time',
        supfs = 18)
# Out:
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# ...

# %%
for patient in critical_patients:
    dataset = df_cyto_crit[df_cyto_crit.patno == patient].reset_index(
        drop=True)
    plot(data=dataset,
         immune='il10',
         noise_name=f'Patient {patient}',
         immune_name='IL10',
         method_name = 'Time-varying AR', 
         method=do_ews_ar,
         win_size=len(dataset) / 2,
         time='time',
         supfs=18)
# Out:
# ...
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/conda/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# ...
